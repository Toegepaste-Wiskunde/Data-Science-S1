# %% [markdown]
# ## Axes
# We've seen that `matplotlib` changes the axes to what it considers best for the current plot. However, sometimes it's better to set it yourself. Here we'll see how to control the Axes (scale, range, and ticks).
#
# We'll again make use of the lines for sphere area and volume:

# %%
## CREATE A FUNCTION
from numpy import pi

sphere_radius = [x/10 for x in range(0,50)]
sphere_area = [4*pi*x**2 for x in sphere_radius]
sphere_volume = [4/3*pi*x**3 for x in sphere_radius]

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots()
ax.grid(True)
ax.plot(sphere_radius,sphere_area, sphere_radius,sphere_volume)
fig

# %% [markdown]
# We can change the scale of an axis from the default linear to logarithmic. Then every tick indicates a multiplication by 10:

# %%
ax.set_yscale('log')
fig

# %% [markdown]
# A logarithmic scale is mostly used for function that change exponentially. That's not the case for our functions so let's set it back to `linear`.
#
# We can change the range of the x-axis that is show using the function `set_xlim`.

# %%
ax.set_yscale('linear')

ax.set_xlim([0,2])
fig

# %% [markdown]
# However, see that the y-axis hasn't updated to fit the lines well. Update it manually to the range `[0,60]`.

# %%
# %%assignment
# ### ENTER YOUR CODE HERE

# %%
# %%check
# result.axes[0].get_ylim()[0] == 0
# result.axes[0].get_ylim()[1] == 60
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('check', '', 'result.axes[0].get_ylim()[0] == 0\nresult.axes[0].get_ylim()[1] == 60\n')
#
# File /opt/jupyterhub/anaconda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File <string>:199, in check(self, nr, checks)
#
# File <string>:231, in check2(self)
#
# File <string>:150, in eval(self, script, prelude)
#
# File /opt/jupyterhub/anaconda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2684, in InteractiveShell.ex(self, cmd)
#    2682 """Execute a normal python statement in user namespace."""
# ...

# %% [markdown]
# We can specify which tick marks to draw:

# %%
ax.set_xticks([0,1,2])
fig

# %% [markdown]
# And also we can set custom labels for the markers:

# %%
ax.set_xticklabels(['zero','one','two'])
fig

# %% [markdown]
# ### Subplots
# The function `subplots` has the option to divide a figure in multiple subfigures. The number of subfigure rows is set using `nrows`, and the number of columns with `ncols`. When there are multiple subplots, the variable `axs` is not an Axes object, but **a list of Axes objects**.

# %%
fig,axs = plt.subplots(nrows=2,ncols=1)
axs[0].plot(sphere_radius,sphere_area, 'r')
axs[0].grid(True)
axs[0].set_ylabel('area')
axs[1].plot(sphere_radius,sphere_volume, 'b')
axs[1].grid(True)
axs[1].set_xlabel('radius')
axs[1].set_ylabel('volume')
fig

# %% [markdown]
# Since both the above subfigures have the same x-range, we can set `sharex` to `True`, which means that the x-axis (range, markers, labels) is shared:

# %%
fig,axs = plt.subplots(nrows=2,ncols=1,sharex=True)
axs[0].plot(sphere_radius,sphere_area, 'r')
axs[0].grid(True)
axs[0].set_ylabel('area')
axs[1].plot(sphere_radius,sphere_volume, 'b')
axs[1].grid(True)
axs[1].set_xlabel('radius')
axs[1].set_ylabel('volume')
axs[1].set_xticks([0,2.5,5])

fig

# %% [markdown]
# ### Exercise
# Recreate the following figure. The positions of the points are given below. The exact figure size and marker style are not necessary.
#
# <img src="fig_exercise.png" alt="fig_test" width="600"/>

# %%
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68] # data set A
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74] # data set B

# %%
# %%assignment
# ### ENTER YOUR CODE HERE

# %%
# %%check
#
# sum(result.axes[0].get_xlim() + result.axes[0].get_ylim() + result.axes[1].get_xlim() + result.axes[1].get_ylim() + tuple(result.axes[1].get_xticks()) + tuple(result.axes[1].get_yticks()) + tuple(result.axes[0].get_xticks()) + tuple(result.axes[0].get_yticks())) == 196
# result.axes[0].get_title() == 'data set A'
# result.axes[1].get_title() == 'data set B'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('check', '', "\nsum(result.axes[0].get_xlim() + result.axes[0].get_ylim() + result.axes[1].get_xlim() + result.axes[1].get_ylim() + tuple(result.axes[1].get_xticks()) + tuple(result.axes[1].get_yticks()) + tuple(result.axes[0].get_xticks()) + tuple(result.axes[0].get_yticks())) == 196\nresult.axes[0].get_title() == 'data set A'\nresult.axes[1].get_title() == 'data set B'\n")
#
# File /opt/jupyterhub/anaconda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File <string>:199, in check(self, nr, checks)
#
# ...
