# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()

# %%
## CREATE A FUNCTION
from numpy import pi
xval = [x/100 for x in range(0,500)]
yval = [4/3*pi*x**3 for x in xval]
yval2 = [4*pi*x**2 for x in xval]

ax.plot(xval,yval,xval,yval2)
fig

# %%
ax.set_xlabel('x values')
ax.set_xlabel('y values')
fig

# %%
ax.set_title('my first figure')
fig

# %%
ax.grid()
fig

# %%
import matplotlib.image as mpimg
img = mpimg.imread('../../doc/_static/stinkbug.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 import matplotlib.image as mpimg
# ----> 2 img = mpimg.imread('../../doc/_static/stinkbug.png')
#
# File /opt/jupyterhub/anaconda/lib/python3.9/site-packages/matplotlib/image.py:1560, in imread(fname, format)
#    1558                 response = io.BytesIO(response.read())
#    1559             return imread(response, format=ext)
# -> 1560 with img_open(fname) as image:
#    1561     return (_pil_png_to_float_array(image)
#    1562             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1563             pil_to_array(image))
#
# File /opt/jupyterhub/anaconda/lib/python3.9/site-packages/PIL/ImageFile.py:104, in ImageFile.__init__(self, fp, filename)
#     100 self.decodermaxblock = MAXBLOCK
#     102 if is_path(fp):
#     103     # filename
# --> 104     self.fp = open(fp, "rb")
#     105     self.filename = fp
#     106     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../doc/_static/stinkbug.png'

# %%
import matplotlib.cbook as cbook
with cbook.get_sample_data('grace_hopper.jpg') as image_file:
    image = plt.imread(image_file)

plt.imshow(image);

# %%
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
import numpy as np


# Data are 256x256 16 bit integers.
with cbook.get_sample_data('s1045.ima.gz') as dfile:
    im = np.frombuffer(dfile.read(), np.uint16).reshape((256, 256))

fig, ax = plt.subplots(num="MRI_demo")
ax.imshow(im, cmap="gray")
ax.axis('off')

plt.show()
